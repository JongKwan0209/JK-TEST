# %%
import pandas as pd
import numpy as np
from statistics import mean
import matplotlib.pylab as plt
import seaborn as sns
import os
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
print(fm.findSystemFonts(fontpaths=None, fontext='ttf'))
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['C:\\WINDOWS\\Fonts\\WINGDNG2.TTF', 'C:\\WINDOWS\\Fonts\\NirmalaS.ttf', 'C:\\WINDOWS\\Fonts\\STXIHEI.TTF', 'C:\\WINDOWS\\Fonts\\BOD_BLAR.TTF', 'C:\\Windows\\Fonts\\javatext.ttf', 'C:\\Windows\\Fonts\\SCHLBKBI.TTF', 'C:\\WINDOWS\\Fonts\\ROCKBI.TTF', 'C:\\WINDOWS\\Fonts\\comicz.ttf', 'C:\\Windows\\Fonts\\webdings.ttf', 'C:\\WINDOWS\\Fonts\\DUBAI-BOLD.TTF', 'C:\\WINDOWS\\Fonts\\seguiemj.ttf', 'C:\\Windows\\Fonts\\BRLNSDB.TTF', 'C:\\WINDOWS\\Fonts\\FZYTK.TTF', 'C:\\WINDOWS\\Fonts\\PLAYBILL.TTF', 'C:\\Windows\\Fonts\\TCBI____.TTF', 'C:\\Windows\\Fonts\\BRITANIC.TTF', 'C:\\Windows\\Fonts\\ERASMD.TTF', 'C:\\Windows\\Fonts\\calibri.ttf', 'C:\\Windows\\Fonts\\HARNGTON.TTF', 'C:\\WINDOWS\\Fonts\\H2MJSM.TTF', 'C:\\WINDOWS\\Fonts\\LeelawUI.ttf', 'C:\\Windows\\Fonts\\BAUHS93.TTF', 'C:\\WINDOWS\\Fonts\\msyhl.ttc', 'C:\\WINDOWS\\Fonts\\msgothic.ttc', 'C:\\Windows\\Fonts\\bahnschrift.ttf', 'C:\\WINDOWS\\Fonts\\SCHLBKBI.TTF', 'C:\\WINDOWS\\Fonts\\tahomabd.ttf', 'C:\\Windows\\Fonts\\verdanaz.ttf', 'C
# ...

# %%
job1 = pd.read_excel("C:/Users/SAMSUNG/Desktop/project/job.xlsx", skiprows = 50)
job1
# Out:
#       년도    직업    전체-남    전체-여  서울중앙-남  서울중앙-여  서울서부-남  서울서부-여  서울남부-남  \
# 0   2012  고등학생  384402  263637       0       0   33562   27516   19013
# 1   2012   대학생  466684  306108       0       0   50066   36210   40268
# 2   2012    군인  356043    2597       0       0   34805     230   39199
# 3   2012   회사원  348427   81125       0       0   44550   13963   41337
# 4   2012   공무원   47354    7448       0       0    3380     634    2680
# ..   ...   ...     ...     ...     ...     ...     ...     ...     ...
# 85  2021   공무원   95486   23634    4405    1039       0       0    4233
# 86  2021   자영업   52385    6794    5078     717       0       0    3427
# 87  2021   종교직    5596     981     559      97       0       0     429
# 88  2021    가사     147   52647      11    4465       0       0       7
# 89  2021    기타  168799   73719   18549    8295       0       0   15810
#
#     서울남부-여  ...  Unnamed: 81  Unnamed: 82  Unnamed: 83  Unnamed: 84  \
# ...

# %%
job2 = job1.drop(['Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', '서울중앙-남', '서울중앙-여', '서울서부-남', '서울서부-여', '서울남부-남', '서울남부-여', '서울동부-남', '서울동부-여', '부산-남', '부산-여', '대구·경북-남', '대구·경북-여', '인천-남', '인천-여', '울산-남', '울산-여', '강원-남', '강원-여', '충북-남', '충북-여', '대전·세종·충남-남', '대전·세종·충남-여', '전북-남', '전북-여', '광주·전남-남', '광주·전남-여', '경남-남', '경남-여', '제주-남', '제주-여'], axis = 1)
job2
# Out:
#       년도    직업    전체-남    전체-여      서울     부산  대구·경북     인천     울산   경기-남  \
# 0   2012  고등학생  384402  263637  172932  49398  55531  59767  24575  28271
# 1   2012   대학생  466684  306108  229390  83525  86700  41998  22171  25032
# 2   2012    군인  356043    2597  107897  21715  27984  15890   4941  21053
# 3   2012   회사원  348427   81125  154664  35243  31332  30860  17932  35749
# 4   2012   공무원   47354    7448   12916   3645   5011   2754   1420   3350
# ..   ...   ...     ...     ...     ...    ...    ...    ...    ...    ...
# 85  2021   공무원   95486   23634   20891   6811   9851   6964   2990   9391
# 86  2021   자영업   52385    6794   16312   4574   5937   4265   1590   5361
# 87  2021   종교직    5596     981    1933    479    593    503    186    564
# 88  2021    가사     147   52647   12341   4463   6409   4536   2385     20
# 89  2021    기타  168799   73719   76973  23393  23178  20022   8005  15759
#
#      경기-여     경기     강원     충북  대전·세종·충남     전북  광주·전남     경남     제주
# ...

# %%
job3 = job2.drop(['서울', '부산', '대구·경북', '인천', '울산', '경기', '강원', '충북', '대전·세종·충남', '전북', '광주·전남', '경남', '제주', '전체-남', '전체-여'], axis = 1)
job3
# Out:
#       년도    직업   경기-남   경기-여
# 0   2012  고등학생  28271  18092
# 1   2012   대학생  25032  14889
# 2   2012    군인  21053    212
# 3   2012   회사원  35749   6692
# 4   2012   공무원   3350    409
# ..   ...   ...    ...    ...
# 85  2021   공무원   9391   2012
# 86  2021   자영업   5361    744
# 87  2021   종교직    564     84
# 88  2021    가사     20   5811
# 89  2021    기타  15759   6618
#
# [90 rows x 4 columns]

# %%
sorted(list(set(job3['년도'])))
# Out:
# [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
sorted(list(set(job3['직업'])))
# Out:
# ['가사', '고등학생', '공무원', '군인', '기타', '대학생', '자영업', '종교직', '회사원']

# %%
job3_2012 = job3[job3['년도']==2012]
job3_2012
# Out:
#      년도    직업   경기-남   경기-여
# 0  2012  고등학생  28271  18092
# 1  2012   대학생  25032  14889
# 2  2012    군인  21053    212
# 3  2012   회사원  35749   6692
# 4  2012   공무원   3350    409
# 5  2012   자영업   4026    268
# 6  2012   종교직    448     35
# 7  2012    가사     15   2791
# 8  2012    기타  10373   4037

# %%
job3_2013 = job3[job3['년도']==2013]
job3_2013
# Out:
#       년도    직업   경기-남   경기-여
# 9   2013  고등학생  27917  18809
# 10  2013   대학생  29210  16716
# 11  2013    군인  23777    170
# 12  2013   회사원  40289   7711
# 13  2013   공무원   3973    504
# 14  2013   자영업   3985    263
# 15  2013   종교직    407     21
# 16  2013    가사     29   2303
# 17  2013    기타  10972   4206

# %%
job3_2014 = job3[job3['년도']==2014]
job3_2014
# Out:
#       년도    직업   경기-남   경기-여
# 18  2014  고등학생  28460  19313
# 19  2014   대학생  33083  17899
# 20  2014    군인  26170    261
# 21  2014   회사원  42709   9067
# 22  2014   공무원   4976    582
# 23  2014   자영업   4260    313
# 24  2014   종교직    423     39
# 25  2014    가사     24   2357
# 26  2014    기타  11862   4408

# %%
job3_2015 = job3[job3['년도']==2015]
job3_2015
# Out:
#       년도    직업   경기-남   경기-여
# 27  2015  고등학생  29477  20717
# 28  2015   대학생  36174  19477
# 29  2015    군인  25368    274
# 30  2015   회사원  45503  10149
# 31  2015   공무원   5380    705
# 32  2015   자영업   4273    363
# 33  2015   종교직    519     21
# 34  2015    가사     25   3007
# 35  2015    기타  12555   4761

# %%
job3_2016 = job3[job3['년도']==2016]
job3_2016
# Out:
#       년도    직업   경기-남   경기-여
# 36  2016  고등학생  27435  16264
# 37  2016   대학생  29198  14340
# 38  2016    군인  26396    240
# 39  2016   회사원  47828  10253
# 40  2016   공무원   5699    739
# 41  2016   자영업   4438    391
# 42  2016   종교직    510     29
# 43  2016    가사     11   3549
# 44  2016    기타  13077   4870

# %%
job3_2017 = job3[job3['년도']==2017]
job3_2017
# Out:
#       년도    직업   경기-남   경기-여
# 45  2017  고등학생  26810  15417
# 46  2017   대학생  29489  14755
# 47  2017    군인  29538    266
# 48  2017   회사원  49701  10961
# 49  2017   공무원   6308    879
# 50  2017   자영업   4325    372
# 51  2017   종교직    504     40
# 52  2017    가사     10   3824
# 53  2017    기타  13045   4569

# %%
job3_2018 = job3[job3['년도']==2018]
job3_2018
# Out:
#       년도    직업   경기-남   경기-여
# 54  2018  고등학생  22008  12810
# 55  2018   대학생  26386  12647
# 56  2018    군인  27690    249
# 57  2018   회사원  54722  12081
# 58  2018   공무원   6993    945
# 59  2018   자영업   4401    392
# 60  2018   종교직    416     28
# 61  2018    가사      9   3766
# 62  2018    기타  13768   4601

# %%
job3_2019 = job3[job3['년도']==2019]
job3_2019
# Out:
#       년도    직업   경기-남   경기-여
# 63  2019  고등학생  23297  14026
# 64  2019   대학생  26099  12915
# 65  2019    군인  23466    330
# 66  2019   회사원  60158  13919
# 67  2019   공무원   7024   1080
# 68  2019   자영업   4472    436
# 69  2019   종교직    388     26
# 70  2019    가사     12   4383
# 71  2019    기타  14019   5120

# %%
job3_2020 = job3[job3['년도']==2020]
job3_2020
# Out:
#       년도    직업   경기-남   경기-여
# 72  2020  고등학생  13605   8441
# 73  2020   대학생  25793  12230
# 74  2020    군인  25878    548
# 75  2020   회사원  73001  18631
# 76  2020   공무원  10805   2449
# 77  2020   자영업   5493    617
# 78  2020   종교직    550     71
# 79  2020    가사     16   5389
# 80  2020    기타  16052   6333

# %%
job3_2021 = job3[job3['년도']==2021]
job3_2021
# Out:
#       년도    직업   경기-남   경기-여
# 81  2021  고등학생  12632   8362
# 82  2021   대학생  30105  13258
# 83  2021    군인  19812    568
# 84  2021   회사원  74958  19677
# 85  2021   공무원   9391   2012
# 86  2021   자영업   5361    744
# 87  2021   종교직    564     84
# 88  2021    가사     20   5811
# 89  2021    기타  15759   6618

# %%
job4_2012 = job3_2012.drop(columns = ['년도'])
job5_2012 = job4_2012.set_index("직업")
job5_2012
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  28271  18092
# 대학생   25032  14889
# 군인    21053    212
# 회사원   35749   6692
# 공무원    3350    409
# 자영업    4026    268
# 종교직     448     35
# 가사       15   2791
# 기타    10373   4037

# %%
job4_2013 = job3_2013.drop(columns = ['년도'])
job5_2013 = job4_2013.set_index("직업")
job5_2013
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  27917  18809
# 대학생   29210  16716
# 군인    23777    170
# 회사원   40289   7711
# 공무원    3973    504
# 자영업    3985    263
# 종교직     407     21
# 가사       29   2303
# 기타    10972   4206

# %%
job4_2014 = job3_2014.drop(columns = ['년도'])
job5_2014 = job4_2014.set_index("직업")
job5_2014
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  28460  19313
# 대학생   33083  17899
# 군인    26170    261
# 회사원   42709   9067
# 공무원    4976    582
# 자영업    4260    313
# 종교직     423     39
# 가사       24   2357
# 기타    11862   4408

# %%
job4_2015 = job3_2015.drop(columns = ['년도'])
job5_2015 = job4_2015.set_index("직업")
job5_2015
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  29477  20717
# 대학생   36174  19477
# 군인    25368    274
# 회사원   45503  10149
# 공무원    5380    705
# 자영업    4273    363
# 종교직     519     21
# 가사       25   3007
# 기타    12555   4761

# %%
job4_2016 = job3_2016.drop(columns = ['년도'])
job5_2016 = job4_2016.set_index("직업")
job5_2016
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  27435  16264
# 대학생   29198  14340
# 군인    26396    240
# 회사원   47828  10253
# 공무원    5699    739
# 자영업    4438    391
# 종교직     510     29
# 가사       11   3549
# 기타    13077   4870

# %%
job4_2017 = job3_2017.drop(columns = ['년도'])
job5_2017 = job4_2017.set_index("직업")
job5_2017
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  26810  15417
# 대학생   29489  14755
# 군인    29538    266
# 회사원   49701  10961
# 공무원    6308    879
# 자영업    4325    372
# 종교직     504     40
# 가사       10   3824
# 기타    13045   4569

# %%
job4_2018 = job3_2018.drop(columns = ['년도'])
job5_2018 = job4_2018.set_index("직업")
job5_2018
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  22008  12810
# 대학생   26386  12647
# 군인    27690    249
# 회사원   54722  12081
# 공무원    6993    945
# 자영업    4401    392
# 종교직     416     28
# 가사        9   3766
# 기타    13768   4601

# %%
job4_2019 = job3_2019.drop(columns = ['년도'])
job5_2019 = job4_2019.set_index("직업")
job5_2019
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  23297  14026
# 대학생   26099  12915
# 군인    23466    330
# 회사원   60158  13919
# 공무원    7024   1080
# 자영업    4472    436
# 종교직     388     26
# 가사       12   4383
# 기타    14019   5120

# %%
job4_2020 = job3_2020.drop(columns = ['년도'])
job5_2020 = job4_2020.set_index("직업")
job5_2020
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  13605   8441
# 대학생   25793  12230
# 군인    25878    548
# 회사원   73001  18631
# 공무원   10805   2449
# 자영업    5493    617
# 종교직     550     71
# 가사       16   5389
# 기타    16052   6333

# %%
job4_2021 = job3_2021.drop(columns = ['년도'])
job5_2021 = job4_2021.set_index("직업")
job5_2021
# Out:
#        경기-남   경기-여
# 직업
# 고등학생  12632   8362
# 대학생   30105  13258
# 군인    19812    568
# 회사원   74958  19677
# 공무원    9391   2012
# 자영업    5361    744
# 종교직     564     84
# 가사       20   5811
# 기타    15759   6618

# %%
job5_location1 = job5_2012.groupby(['직업'])
job5_location1
plt.figure(figsize=(8,10))
job5_2012_graph = job5_2012.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2012년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location2 = job5_2013.groupby(['직업'])
job5_location2
plt.figure(figsize=(8,10))
job5_2013_graph = job5_2013.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2013년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location3 = job5_2014.groupby(['직업'])
job5_location3
plt.figure(figsize=(8,10))
job5_2014_graph = job5_2014.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2014년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location4 = job5_2015.groupby(['직업'])
job5_location4
plt.figure(figsize=(8,10))
job5_2015_graph = job5_2015.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2015년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location5 = job5_2016.groupby(['직업'])
job5_location5
plt.figure(figsize=(8,10))
job5_2016_graph = job5_2016.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2016년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location6 = job5_2017.groupby(['직업'])
job5_location6
plt.figure(figsize=(8,10))
job5_2017_graph = job5_2017.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2017년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location7 = job5_2018.groupby(['직업'])
job5_location7
plt.figure(figsize=(8,10))
job5_2018_graph = job5_2018.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2018년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location8 = job5_2019.groupby(['직업'])
job5_location8
plt.figure(figsize=(8,10))
job5_2019_graph = job5_2019.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2019년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location9 = job5_2020.groupby(['직업'])
job5_location9
plt.figure(figsize=(8,10))
job5_2020_graph = job5_2020.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2020년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

job5_location10 = job5_2021.groupby(['직업'])
job5_location10
plt.figure(figsize=(8,10))
job5_2021_graph = job5_2021.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2021년 직업별 헌혈실적')
plt.ylabel("실적")
plt.show()

# %%
job5_2012.plot()
plt.title('2012년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2013.plot()
plt.title('2013년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2014.plot()
plt.title('2014년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2015.plot()
plt.title('2015년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2016.plot()
plt.title('2016년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2017.plot()
plt.title('2017년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2018.plot()
plt.title('2018년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2019.plot()
plt.title('2019년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2020.plot()
plt.title('2020년 직업별 헌혈실적')
plt.ylabel("실적")

job5_2021.plot()
plt.title('2021년 직업별 헌혈실적')
plt.ylabel("실적")
# Out:
# Text(0, 0.5, '실적')
