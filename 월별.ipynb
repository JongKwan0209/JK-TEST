# %%
import pandas as pd
import numpy as np
from statistics import mean
import matplotlib.pylab as plt
import seaborn as sns
import os
import matplotlib as mpl 
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
m = pd.read_excel("C:/Users/SAMSUNG/Desktop/project/month1.xlsx")
m
# Out:
#             월별  농축적혈구  농축혈소판  신선동결혈장  백혈구여과제거성분채혈혈소판
# 0     2012년 1월  14123   9112   80467             591
# 1     2012년 2월  24209  10381   97466             641
# 2     2012년 3월  19736   9313   90576             574
# 3     2012년 4월  18544   9991   87092             556
# 4     2012년 5월  30857  10558   96051             552
# ..         ...    ...    ...     ...             ...
# 115   2021년 8월  13276   6770   88483             984
# 116   2021년 9월  14522   6631   91495             917
# 117  2021년 10월  14197   6167   89813             899
# 118  2021년 11월  16433   7422   97566             962
# 119  2021년 12월  24474   7356  102600             878
#
# [120 rows x 5 columns]

# %%
m['월별'].unique()
# Out:
# array(['2012년 1월', '2012년 2월', '2012년 3월', '2012년 4월', '2012년 5월',
#        '2012년 6월', '2012년 7월', '2012년 8월', '2012년 9월', '2012년 10월',
#        '2012년 11월', '2012년 12월', '2013년 1월', '2013년 2월', '2013년 3월',
#        '2013년 4월', '2013년 5월', '2013년 6월', '2013년 7월', '2013년 8월',
#        '2013년 9월', '2013년 10월', '2013년 11월', '2013년 12월', '2014년 1월',
#        '2014년 2월', '2014년 3월', '2014년 4월', '2014년 5월', '2014년 6월',
#        '2014년 7월', '2014년 8월', '2014년 9월', '2014년 10월', '2014년 11월',
#        '2014년 12월', '2015년 1월', '2015년 2월', '2015년 3월', '2015년 4월',
#        '2015년 5월', '2015년 6월', '2015년 7월', '2015년 8월', '2015년 9월',
#        '2015년 10월', '2015년 11월', '2015년 12월', '2016년 1월', '2016년 2월',
#        '2016년 3월', '2016년 4월', '2016년 5월', '2016년 6월', '2016년 7월',
#        '2016년 8월', '2016년 9월', '2016년 10월', '2016년 11월', '2016년 12월',
#        '2017년 1월', '2017년 2월', '2017년 3월', '2017년 4월', '2017년 5월',
#        '2017년 6월', '2017년 7월', '2017년 8월', '2017년 9월', '2017년 10월',
# ...

# %%
m1 = m[['월별', '농축적혈구']]
m1_1 = m1.set_index("월별")
m1_1
# Out:
#            농축적혈구
# 월별
# 2012년 1월   14123
# 2012년 2월   24209
# 2012년 3월   19736
# 2012년 4월   18544
# 2012년 5월   30857
# ...          ...
# 2021년 8월   13276
# 2021년 9월   14522
# 2021년 10월  14197
# 2021년 11월  16433
# 2021년 12월  24474
#
# [120 rows x 1 columns]

# %%
m2 = m[['월별', '농축혈소판']]
m2_1 = m2.set_index("월별")
m2_1
# Out:
#            농축혈소판
# 월별
# 2012년 1월    9112
# 2012년 2월   10381
# 2012년 3월    9313
# 2012년 4월    9991
# 2012년 5월   10558
# ...          ...
# 2021년 8월    6770
# 2021년 9월    6631
# 2021년 10월   6167
# 2021년 11월   7422
# 2021년 12월   7356
#
# [120 rows x 1 columns]

# %%
m3 = m[['월별', '신선동결혈장']]
m3_1 = m3.set_index("월별")
m3_1
# Out:
#            신선동결혈장
# 월별
# 2012년 1월    80467
# 2012년 2월    97466
# 2012년 3월    90576
# 2012년 4월    87092
# 2012년 5월    96051
# ...           ...
# 2021년 8월    88483
# 2021년 9월    91495
# 2021년 10월   89813
# 2021년 11월   97566
# 2021년 12월  102600
#
# [120 rows x 1 columns]

# %%
m4 = m[['월별', '백혈구여과제거성분채혈혈소판']]
m4_1 = m4.set_index("월별")
m4_1
# Out:
#            백혈구여과제거성분채혈혈소판
# 월별
# 2012년 1월              591
# 2012년 2월              641
# 2012년 3월              574
# 2012년 4월              556
# 2012년 5월              552
# ...                   ...
# 2021년 8월              984
# 2021년 9월              917
# 2021년 10월             899
# 2021년 11월             962
# 2021년 12월             878
#
# [120 rows x 1 columns]

# %%
m.plot()
# Out:
# <AxesSubplot:>

# %%
m1_1.plot(figsize = (8,5))
plt.ylabel("unit")
plt.title('농축적혈구 월평균 보유 추이')

m2_1.plot(figsize = (8,5))
plt.ylabel("unit")
plt.title('농축혈소판 월평균 보유 추이')

m3_1.plot(figsize = (8,5))
plt.ylabel("unit")
plt.title('신선동결혈장 월평균 보유 추이')

m4_1.plot(figsize = (8,5))
plt.ylabel("unit")
plt.title('백혈구여과제거성분채혈혈소판 월평균 보유 추이')
# Out:
# Text(0.5, 1.0, '백혈구여과제거성분채혈혈소판 월평균 보유 추이')
