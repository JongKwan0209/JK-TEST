# %%
import pandas as pd
import numpy as np
from statistics import mean
import matplotlib.pylab as plt
import seaborn as sns
import os
import matplotlib as mpl 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
print(fm.findSystemFonts(fontpaths=None, fontext='ttf'))
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['C:\\Windows\\Fonts\\BASKVILL.TTF', 'C:\\WINDOWS\\Fonts\\GILSANUB.TTF', 'C:\\Windows\\Fonts\\COPRGTB.TTF', 'C:\\Windows\\Fonts\\georgiai.ttf', 'C:\\WINDOWS\\Fonts\\ROCKBI.TTF', 'C:\\WINDOWS\\Fonts\\TCCM____.TTF', 'C:\\Windows\\Fonts\\LCALLIG.TTF', 'C:\\Windows\\Fonts\\LBRITED.TTF', 'C:\\WINDOWS\\Fonts\\comicbd.ttf', 'C:\\WINDOWS\\Fonts\\FREESCPT.TTF', 'C:\\WINDOWS\\Fonts\\BSSYM7.TTF', 'C:\\Windows\\Fonts\\GOUDOS.TTF', 'C:\\WINDOWS\\Fonts\\HANDotumB.ttf', 'C:\\Windows\\Fonts\\taileb.ttf', 'C:\\WINDOWS\\Fonts\\ELEPHNTI.TTF', 'C:\\Windows\\Fonts\\GARAIT.TTF', 'C:\\WINDOWS\\Fonts\\OCRAEXT.TTF', 'C:\\WINDOWS\\Fonts\\georgiab.ttf', 'C:\\Windows\\Fonts\\SIMLI.TTF', 'C:\\Windows\\Fonts\\gadugi.ttf', 'C:\\Windows\\Fonts\\H2PORM.TTF', 'C:\\Windows\\Fonts\\H2GPRM.TTF', 'C:\\WINDOWS\\Fonts\\POORICH.TTF', 'C:\\WINDOWS\\Fonts\\LSANSI.TTF', 'C:\\WINDOWS\\Fonts\\TCM_____.TTF', 'C:\\WINDOWS\\Fonts\\Candarai.ttf', 'C:\\Windows\\Fonts\\HANBatangExt.ttf', 'C:\\Windows\\Fonts\\JUICE___.TTF', 'C:\\WINDOW
# ...

# %%
blood1 = pd.read_excel("C:/Users/SAMSUNG/Desktop/project/location.xlsx", skiprows = 8)
blood2 = blood1.drop(['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80'], axis = 1)
blood2
# Out:
#       년도 단체헌혈 또는 개인헌혈  지역    장소       남      여
# 0   2012         단체헌혈  경기  고등학교   17272   7001
# 1   2012         단체헌혈  경기   대학교    2015   1047
# 2   2012         단체헌혈  경기   군부대   16261    102
# 3   2012         단체헌혈  경기    종교     100    633
# 4   2012         단체헌혈  경기  일반단체   10813   1822
# ..   ...          ...  ..   ...     ...    ...
# 75  2021         단체헌혈  경기    종교     195    257
# 76  2021         단체헌혈  경기  일반단체   14104   5891
# 77  2021         개인헌혈  경기    원내    3440    948
# 78  2021         개인헌혈  경기  헌혈의집  129385  47263
# 79  2021         개인헌혈  경기    가두       0      0
#
# [80 rows x 6 columns]

# %%
blood2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   년도            80 non-null     int64
#  1   단체헌혈 또는 개인헌혈  80 non-null     object
#  2   지역            80 non-null     object
#  3   장소            80 non-null     object
#  4   남             80 non-null     int64
#  5   여             80 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3
# 군부대   17143     78
# 종교        0      0
# 일반단체  12286   1948
# 원내     4253    996
# 헌혈의집  85570  38372
# 가두      529    193

# %%
blood3_2014 = blood2_2014.drop(columns = ['단체헌혈 또는 개인헌혈', '지역', '년도'])
blood4_2014 = blood3_2014.set_index("장소")
blood4_2014
# Out:
#           남      여
# 장소
# 고등학교  18864   8682
# 대학교    3604   1748
# 군부대   18686    159
# 종교       79     51
# 일반단체  13078   2713
# 원내     4420   1107
# 헌혈의집  92494  39291
# 가두      742    488

# %%
blood3_2015 = blood2_2015.drop(columns = ['단체헌혈 또는 개인헌혈', '지역', '년도'])
blood4_2015 = blood3_2015.set_index("장소")
blood4_2015
# Out:
#            남      여
# 장소
# 고등학교   17707   8813
# 대학교     4827   2363
# 군부대    16945    139
# 종교        31    206
# 일반단체   13625   2752
# 원내      5103   1554
# 헌혈의집  100228  43177
# 가두       808    470

# %%
blood3_2016 = blood2_2016.drop(columns = ['단체헌혈 또는 개인헌혈', '지역', '년도'])
blood4_2016 = blood3_2016.set_index("장소")
blood4_2016
# Out:
#           남      여
# 장소
# 고등학교  19690   9126
# 대학교    4240   2182
# 군부대   18159    154
# 종교       73    384
# 일반단체  14396   2955
# 원내     5440   1606
# 헌혈의집  92594  34268
# 가두        0      0

# %%
blood3_2017 = blood2_2017.drop(columns = ['단체헌혈 또는 개인헌혈', '지역', '년도'])
blood4_2017 = blood3_2017.set_index("장소")
blood4_2017
# Out:
#           남      여
# 장소
# 고등학교  17977   8189
# 대학교    5359   3180
# 군부대   21311    184
# 종교      114    450
# 일반단체  12595   2954
# 원내     5658   1681
# 헌혈의집  96716  34445
# 가두        0      0

# %%
blood3_2018 = blood2_2018.drop(columns = ['단체헌혈 또는 개인헌혈', '지역', '년도'])
blood4_2018 = blood3_2018.set_index("장소")
blood4_2018
# Out:
#            남      여
# 장소
# 고등학교   13471   6013
# 대학교     3805   1904
# 군부대    18486    184
# 종교       103    360
# 일반단체   12773   2878
# 원내      5270   1424
# 헌혈의집  102485  34756
# 가두         0      0

# %%
blood3_2019 = blood2_2019.drop(columns = ['단체헌혈 또는 개인헌혈', '지역', '년도'])
blood4_2019 = blood3_2019.set_index("장소")
blood4_2019
# Out:
#            남      여
# 장소
# 고등학교   14819   7710
# 대학교     5126   2701
# 군부대    16307    238
# 종교        89    385
# 일반단체   12726   3590
# 원내      4434   1295
# 헌혈의집  105434  36316
# 가두         0      0

# %%
blood3_2020 = blood2_2020.drop(columns = ['단체헌혈 또는 개인헌혈', '지역', '년도'])
blood4_2020 = blood3_2020.set_index("장소")
blood4_2020
# Out:
#            남      여
# 장소
# 고등학교    4044   1296
# 대학교      898    306
# 군부대    22272    471
# 종교        60     57
# 일반단체   16676   6817
# 원내      4634   1407
# 헌혈의집  122609  44355
# 가두         0      0

# %%
blood3_2021 = blood2_2021.drop(columns = ['단체헌혈 또는 개인헌혈', '지역', '년도'])
blood4_2021 = blood3_2021.set_index("장소")
blood4_2021
# Out:
#            남      여
# 장소
# 고등학교    4019   1657
# 대학교     1005    596
# 군부대    16454    522
# 종교       195    257
# 일반단체   14104   5891
# 원내      3440    948
# 헌혈의집  129385  47263
# 가두         0      0

# %%
blood4_location1 = blood4_2012.groupby(['장소'])
blood4_location1
plt.figure(figsize=(8,10))
blood2012_graph = blood4_2012.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2012년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location2 = blood4_2013.groupby(['장소'])
blood4_location2
plt.figure(figsize=(8,10))
blood2013_graph = blood4_2013.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2013년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location3 = blood4_2014.groupby(['장소'])
blood4_location3
plt.figure(figsize=(8,10))
blood2014_graph = blood4_2014.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2014년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location4 = blood4_2015.groupby(['장소'])
blood4_location4
plt.figure(figsize=(8,10))
blood2015_graph = blood4_2015.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2015년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location5 = blood4_2016.groupby(['장소'])
blood4_location5
plt.figure(figsize=(8,10))
blood2016_graph = blood4_2016.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2016년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location6 = blood4_2017.groupby(['장소'])
blood4_location6
plt.figure(figsize=(8,10))
blood2017_graph = blood4_2017.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2017년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location7 = blood4_2018.groupby(['장소'])
blood4_location7
plt.figure(figsize=(8,10))
blood2018_graph = blood4_2018.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2018년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location8 = blood4_2019.groupby(['장소'])
blood4_location8
plt.figure(figsize=(8,10))
blood2019_graph = blood4_2019.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2019년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location9 = blood4_2020.groupby(['장소'])
blood4_location9
plt.figure(figsize=(8,10))
blood2020_graph = blood4_2020.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2020년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

blood4_location10 = blood4_2021.groupby(['장소'])
blood4_location10
plt.figure(figsize=(8,10))
blood2021_graph = blood4_2021.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2021년 장소별 헌혈실적')
plt.ylabel("실적")
plt.show()

# %%
blood4_2012.plot()
plt.title('2012년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2013.plot()
plt.title('2013년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2014.plot()
plt.title('2014년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2015.plot()
plt.title('2015년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2016.plot()
plt.title('2016년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2017.plot()
plt.title('2017년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2018.plot()
plt.title('2018년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2019.plot()
plt.title('2019년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2020.plot()
plt.title('2020년 장소별 헌혈실적')
plt.ylabel("실적")

blood4_2021.plot()
plt.title('2021년 장소별 헌혈실적')
plt.ylabel("실적")
# Out:
# Text(0, 0.5, '실적')
