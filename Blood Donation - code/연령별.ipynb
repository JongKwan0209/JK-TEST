# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
print(fm.findSystemFonts(fontpaths=None, fontext='ttf'))
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['C:\\Windows\\Fonts\\ROCC____.TTF', 'C:\\WINDOWS\\Fonts\\seguisli.ttf', 'C:\\Windows\\Fonts\\comic.ttf', 'C:\\Windows\\Fonts\\ROCK.TTF', 'C:\\WINDOWS\\Fonts\\ARIALNI.TTF', 'C:\\WINDOWS\\Fonts\\MTCORSVA.TTF', 'C:\\Windows\\Fonts\\calibri.ttf', 'C:\\WINDOWS\\Fonts\\Gabriola.ttf', 'C:\\Windows\\Fonts\\BOD_CR.TTF', 'C:\\Windows\\Fonts\\l_10646.ttf', 'C:\\Windows\\Fonts\\REFSAN.TTF', 'C:\\WINDOWS\\Fonts\\DUBAI-MEDIUM.TTF', 'C:\\WINDOWS\\Fonts\\mmrtext.ttf', 'C:\\Windows\\Fonts\\Hancom Gothic Bold.ttf', 'C:\\Windows\\Fonts\\GIL_____.TTF', 'C:\\Windows\\Fonts\\palabi.ttf', 'C:\\Windows\\Fonts\\ROCKB.TTF', 'C:\\Windows\\Fonts\\HMKMMAG.TTF', 'C:\\Windows\\Fonts\\SCRIPTBL.TTF', 'C:\\Windows\\Fonts\\DUBAI-BOLD.TTF', 'C:\\WINDOWS\\Fonts\\CASTELAR.TTF', 'C:\\WINDOWS\\Fonts\\msjhbd.ttc', 'C:\\Windows\\Fonts\\corbelz.ttf', 'C:\\WINDOWS\\Fonts\\gadugib.ttf', 'C:\\Windows\\Fonts\\ROCKBI.TTF', 'C:\\WINDOWS\\Fonts\\PERTILI.TTF', 'C:\\WINDOWS\\Fonts\\ROCKB.TTF', 'C:\\WINDOWS\\Fonts\\LeelawUI.ttf', 'C:\
# ...

# %%
age = pd.read_excel("C:/Users/SAMSUNG/Desktop/project/age.xlsx", skiprows=7)
age2 = age.drop(['Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60'], axis = 1)
age2
# Out:
#       년도     연령별  지역      남      여
# 0   2012  16~19세  경기  38703  24851
# 1   2012  20~29세  경기  47964  14743
# 2   2012  30~39세  경기  24346   4710
# 3   2012  40~49세  경기  12391   2334
# 4   2012  50~59세  경기   4426    720
# 5   2012   60세이상  경기    487     67
# 6   2013  16~19세  경기  38780  25972
# 7   2013  20~29세  경기  55392  16678
# 8   2013  30~39세  경기  26217   4838
# 9   2013  40~49세  경기  14205   2369
# 10  2013  50~59세  경기   5284    763
# 11  2013   60세이상  경기    681     83
# 12  2014  16~19세  경기  39954  26624
# 13  2014  20~29세  경기  61530  18459
# 14  2014  30~39세  경기  27014   5234
# 15  2014  40~49세  경기  16567   2764
# 16  2014  50~59세  경기   6095   1001
# 17  2014   60세이상  경기    807    157
# 18  2015  16~19세  경기  41308  28302
# 19  2015  20~29세  경기  63689  20080
# 20  2015  30~39세  경기  27602   5943
# 21  2015  40~49세  경기  18964   3762
# 22  2015  50~59세  경기   6774   1233
# 23  2015   60세이상  경기    937    154
# 24  2016  16~19세  경기  38543  21622
# 25  2016  20~29세  경기  57020  15959
# ...

# %%
from statsmodels.formula.api import ols

# %%
res = ols('지역 ~ 남', data = age2).fit()
res

# %%
res.summary()
# Out:
# C:\Users\SAMSUNG\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\SAMSUNG\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1825: RuntimeWarning: invalid value encountered in double_scalars
#   return self.mse_model/self.mse_resid
# C:\Users\SAMSUNG\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\SAMSUNG\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in double_scalars
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 지역[경기]   R-squared:                         nan
# ...

# %%
sorted(list(set(age2['년도'])))
# Out:
# [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
sorted(list(set(age2['연령별'])))
# Out:
# ['16~19세', '20~29세', '30~39세', '40~49세', '50~59세', '60세이상']

# %%
sorted(list(set(age2['지역'])))
# Out:
# ['경기']

# %%
age2_2012 = age2[age2['년도']==2012]
age2_2012
# Out:
#      년도     연령별  지역      남      여
# 0  2012  16~19세  경기  38703  24851
# 1  2012  20~29세  경기  47964  14743
# 2  2012  30~39세  경기  24346   4710
# 3  2012  40~49세  경기  12391   2334
# 4  2012  50~59세  경기   4426    720
# 5  2012   60세이상  경기    487     67

# %%
age2_2013 = age2[age2['년도']==2013]
age2_2013
# Out:
#       년도     연령별  지역      남      여
# 6   2013  16~19세  경기  38780  25972
# 7   2013  20~29세  경기  55392  16678
# 8   2013  30~39세  경기  26217   4838
# 9   2013  40~49세  경기  14205   2369
# 10  2013  50~59세  경기   5284    763
# 11  2013   60세이상  경기    681     83

# %%
age2_2014 = age2[age2['년도']==2014]
age2_2014
# Out:
#       년도     연령별  지역      남      여
# 12  2014  16~19세  경기  39954  26624
# 13  2014  20~29세  경기  61530  18459
# 14  2014  30~39세  경기  27014   5234
# 15  2014  40~49세  경기  16567   2764
# 16  2014  50~59세  경기   6095   1001
# 17  2014   60세이상  경기    807    157

# %%
age2_2015 = age2[age2['년도']==2015]
age2_2015
# Out:
#       년도     연령별  지역      남      여
# 18  2015  16~19세  경기  41308  28302
# 19  2015  20~29세  경기  63689  20080
# 20  2015  30~39세  경기  27602   5943
# 21  2015  40~49세  경기  18964   3762
# 22  2015  50~59세  경기   6774   1233
# 23  2015   60세이상  경기    937    154

# %%
age2_2016 = age2[age2['년도']==2016]
age2_2016
# Out:
#       년도     연령별  지역      남      여
# 24  2016  16~19세  경기  38543  21622
# 25  2016  20~29세  경기  57020  15959
# 26  2016  30~39세  경기  27730   6591
# 27  2016  40~49세  경기  22223   4741
# 28  2016  50~59세  경기   7872   1567
# 29  2016   60세이상  경기   1204    195

# %%
age2_2017 = age2[age2['년도']==2017]
age2_2017
# Out:
#       년도     연령별  지역      남      여
# 30  2017  16~19세  경기  38229  21029
# 31  2017  20~29세  경기  59583  16017
# 32  2017  30~39세  경기  27866   6886
# 33  2017  40~49세  경기  23876   5065
# 34  2017  50~59세  경기   8842   1812
# 35  2017   60세이상  경기   1334    274

# %%
age2_2018 = age2[age2['년도']==2018]
age2_2018
# Out:
#       년도     연령별  지역      남      여
# 36  2018  16~19세  경기  31027  17087
# 37  2018  20~29세  경기  58539  15340
# 38  2018  30~39세  경기  29386   7233
# 39  2018  40~49세  경기  25695   5550
# 40  2018  50~59세  경기  10239   2015
# 41  2018   60세이상  경기   1507    294

# %%
age2_2019 = age2[age2['년도']==2019]
age2_2019
# Out:
#       년도     연령별  지역      남      여
# 42  2019  16~19세  경기  32679  18733
# 43  2019  20~29세  경기  52877  15893
# 44  2019  30~39세  경기  30458   7868
# 45  2019  40~49세  경기  28709   6596
# 46  2019  50~59세  경기  12283   2721
# 47  2019   60세이상  경기   1929    424

# %%
age2_2020 = age2[age2['년도']==2020]
age2_2020
# Out:
#       년도     연령별  지역      남      여
# 48  2020  16~19세  경기  22913  12141
# 49  2020  20~29세  경기  56816  17866
# 50  2020  30~39세  경기  33627   9796
# 51  2020  40~49세  경기  36859   9717
# 52  2020  50~59세  경기  18116   4449
# 53  2020   60세이상  경기   2862    740

# %%
age2_2021 = age2[age2['년도']==2021]
age2_2021
# Out:
#       년도     연령별  지역      남      여
# 54  2021  16~19세  경기  23657  12324
# 55  2021  20~29세  경기  54011  18947
# 56  2021  30~39세  경기  32414  10022
# 57  2021  40~49세  경기  36133  10223
# 58  2021  50~59세  경기  19213   4867
# 59  2021   60세이상  경기   3174    751

# %%
age3_2012 = age2_2012.drop(columns = ['년도'])
age4_2012 = age3_2012.set_index("연령별")
age4_2012
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  38703  24851
# 20~29세  경기  47964  14743
# 30~39세  경기  24346   4710
# 40~49세  경기  12391   2334
# 50~59세  경기   4426    720
# 60세이상   경기    487     67

# %%
age3_2013 = age2_2013.drop(columns = ['년도'])
age4_2013 = age3_2013.set_index("연령별")
age4_2013
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  38780  25972
# 20~29세  경기  55392  16678
# 30~39세  경기  26217   4838
# 40~49세  경기  14205   2369
# 50~59세  경기   5284    763
# 60세이상   경기    681     83

# %%
age3_2014 = age2_2014.drop(columns = ['년도'])
age4_2014 = age3_2014.set_index("연령별")
age4_2014
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  39954  26624
# 20~29세  경기  61530  18459
# 30~39세  경기  27014   5234
# 40~49세  경기  16567   2764
# 50~59세  경기   6095   1001
# 60세이상   경기    807    157

# %%
age3_2015 = age2_2015.drop(columns = ['년도'])
age4_2015 = age3_2015.set_index("연령별")
age4_2015
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  41308  28302
# 20~29세  경기  63689  20080
# 30~39세  경기  27602   5943
# 40~49세  경기  18964   3762
# 50~59세  경기   6774   1233
# 60세이상   경기    937    154

# %%
age3_2016 = age2_2016.drop(columns = ['년도'])
age4_2016 = age3_2016.set_index("연령별")
age4_2016
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  38543  21622
# 20~29세  경기  57020  15959
# 30~39세  경기  27730   6591
# 40~49세  경기  22223   4741
# 50~59세  경기   7872   1567
# 60세이상   경기   1204    195

# %%
age3_2017 = age2_2017.drop(columns = ['년도'])
age4_2017 = age3_2017.set_index("연령별")
age4_2017
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  38229  21029
# 20~29세  경기  59583  16017
# 30~39세  경기  27866   6886
# 40~49세  경기  23876   5065
# 50~59세  경기   8842   1812
# 60세이상   경기   1334    274

# %%
age3_2018 = age2_2018.drop(columns = ['년도'])
age4_2018 = age3_2018.set_index("연령별")
age4_2018
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  31027  17087
# 20~29세  경기  58539  15340
# 30~39세  경기  29386   7233
# 40~49세  경기  25695   5550
# 50~59세  경기  10239   2015
# 60세이상   경기   1507    294

# %%
age3_2019 = age2_2019.drop(columns = ['년도'])
age4_2019 = age3_2019.set_index("연령별")
age4_2019
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  32679  18733
# 20~29세  경기  52877  15893
# 30~39세  경기  30458   7868
# 40~49세  경기  28709   6596
# 50~59세  경기  12283   2721
# 60세이상   경기   1929    424

# %%
age3_2020 = age2_2020.drop(columns = ['년도'])
age4_2020 = age3_2020.set_index("연령별")
age4_2020
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  22913  12141
# 20~29세  경기  56816  17866
# 30~39세  경기  33627   9796
# 40~49세  경기  36859   9717
# 50~59세  경기  18116   4449
# 60세이상   경기   2862    740

# %%
age3_2021 = age2_2021.drop(columns = ['년도'])
age4_2021 = age3_2021.set_index("연령별")
age4_2021
# Out:
#         지역      남      여
# 연령별
# 16~19세  경기  23657  12324
# 20~29세  경기  54011  18947
# 30~39세  경기  32414  10022
# 40~49세  경기  36133  10223
# 50~59세  경기  19213   4867
# 60세이상   경기   3174    751

# %%
age4_location1 = age4_2012.groupby(['연령별'])
age4_location1
plt.figure(figsize=(8,10))
age4_2012_graph = age4_2012.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2012년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location2 = age4_2013.groupby(['연령별'])
age4_location2
plt.figure(figsize=(8,10))
age4_2013_graph = age4_2013.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2013년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location3 = age4_2014.groupby(['연령별'])
age4_location3
plt.figure(figsize=(8,10))
age4_2014_graph = age4_2014.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2014년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location4 = age4_2015.groupby(['연령별'])
age4_location4
plt.figure(figsize=(8,10))
age4_2015_graph = age4_2015.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2015년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location5 = age4_2016.groupby(['연령별'])
age4_location5
plt.figure(figsize=(8,10))
age4_2016_graph = age4_2016.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2016년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location6 = age4_2017.groupby(['연령별'])
age4_location6
plt.figure(figsize=(8,10))
age4_2017_graph = age4_2017.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2017년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location7 = age4_2018.groupby(['연령별'])
age4_location7
plt.figure(figsize=(8,10))
age4_2018_graph = age4_2018.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2018년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location8 = age4_2019.groupby(['연령별'])
age4_location8
plt.figure(figsize=(8,10))
age4_2019_graph = age4_2019.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2019년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location9 = age4_2020.groupby(['연령별'])
age4_location9
plt.figure(figsize=(8,10))
age4_2020_graph = age4_2020.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2020년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

age4_location10 = age4_2021.groupby(['연령별'])
age4_location10
plt.figure(figsize=(8,10))
age4_2021_graph = age4_2021.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2021년 연령별 헌혈실적')
plt.ylabel("실적")
plt.show()

# %%
age4_2012.plot()
plt.ylabel("실적")
plt.title('2012년 연령별 헌혈실적')

age4_2013.plot()
plt.ylabel("실적")
plt.title('2013년 연령별 헌혈실적')

age4_2014.plot()
plt.ylabel("실적")
plt.title('2014년 연령별 헌혈실적')

age4_2015.plot()
plt.ylabel("실적")
plt.title('2015년 연령별 헌혈실적')

age4_2016.plot()
plt.ylabel("실적")
plt.title('2016년 연령별 헌혈실적')

age4_2017.plot()
plt.ylabel("실적")
plt.title('2017년 연령별 헌혈실적')

age4_2018.plot()
plt.ylabel("실적")
plt.title('2018년 연령별 헌혈실적')

age4_2019.plot()
plt.ylabel("실적")
plt.title('2019년 연령별 헌혈실적')

age4_2020.plot()
plt.ylabel("실적")
plt.title('2020년 연령별 헌혈실적')

age4_2021.plot()
plt.ylabel("실적")
plt.title('2021년 연령별 헌혈실적')
# Out:
# Text(0.5, 1.0, '2021년 연령별 헌혈실적')
