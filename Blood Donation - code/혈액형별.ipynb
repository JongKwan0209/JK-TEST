# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
print(fm.findSystemFonts(fontpaths=None, fontext='ttf'))
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['C:\\WINDOWS\\Fonts\\GOUDOSB.TTF', 'C:\\WINDOWS\\Fonts\\ELEPHNTI.TTF', 'C:\\WINDOWS\\Fonts\\MATURASC.TTF', 'C:\\WINDOWS\\Fonts\\timesi.ttf', 'C:\\WINDOWS\\Fonts\\constani.ttf', 'C:\\Windows\\Fonts\\ARIALNBI.TTF', 'C:\\Windows\\Fonts\\cambria.ttc', 'C:\\WINDOWS\\Fonts\\msyhbd.ttc', 'C:\\WINDOWS\\Fonts\\PERBI___.TTF', 'C:\\Windows\\Fonts\\HMKMRHD.TTF', 'C:\\WINDOWS\\Fonts\\ITCBLKAD.TTF', 'C:\\Windows\\Fonts\\GILLUBCD.TTF', 'C:\\WINDOWS\\Fonts\\seguili.ttf', 'C:\\WINDOWS\\Fonts\\ARIALNB.TTF', 'C:\\Windows\\Fonts\\MISTRAL.TTF', 'C:\\WINDOWS\\Fonts\\CALISTB.TTF', 'C:\\WINDOWS\\Fonts\\STFANGSO.TTF', 'C:\\WINDOWS\\Fonts\\HANDotumB.ttf', 'C:\\Windows\\Fonts\\BERNHC.TTF', 'C:\\Windows\\Fonts\\ITCBLKAD.TTF', 'C:\\Windows\\Fonts\\segmdl2.ttf', 'C:\\Windows\\Fonts\\ariblk.ttf', 'C:\\Windows\\Fonts\\calibriz.ttf', 'C:\\Windows\\Fonts\\H2HDRM.TTF', 'C:\\WINDOWS\\Fonts\\MAIAN.TTF', 'C:\\Windows\\Fonts\\COOPBL.TTF', 'C:\\WINDOWS\\Fonts\\taileb.ttf', 'C:\\WINDOWS\\Fonts\\FORTE.TTF', 'C:\\Windows\\Fo
# ...

# %%
type = pd.read_excel("C:/Users/SAMSUNG/Desktop/project/type.xlsx", skiprows=7)
type2 = type.drop(['Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80'], axis = 1)
type2
# Out:
#       년도        혈액형별  지역      남      여
# 0   2012   O형(RH(+))  경기  34967  13183
# 1   2012   A형(RH(+))  경기  43734  15495
# 2   2012   B형(RH(+))  경기  34173  13135
# 3   2012  AB형(RH(+))  경기  14840   5371
# 4   2012   O형(RH(-))  경기    167     69
# ..   ...         ...  ..    ...    ...
# 75  2021  AB형(RH(+))  경기  19591   6468
# 76  2021   O형(RH(-))  경기    232     92
# 77  2021   A형(RH(-))  경기    288    109
# 78  2021   B형(RH(-))  경기    211     92
# 79  2021  AB형(RH(-))  경기    127     40
#
# [80 rows x 5 columns]

# %%
sorted(list(set(type['년도'])))
# Out:
# [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
sorted(list(set(type2['혈액형별'])))
# Out:
# ['AB형(RH(+))',
#  'AB형(RH(-))',
#  'A형(RH(+))',
#  'A형(RH(-))',
#  'B형(RH(+))',
#  'B형(RH(-))',
#  'O형(RH(+))',
#  'O형(RH(-))']

# %%
sorted(list(set(type2['지역'])))
# Out:
# ['경기']

# %%
type2_2012 = type2[type2['년도']==2012]
type2_2012
# Out:
#      년도        혈액형별  지역      남      여
# 0  2012   O형(RH(+))  경기  34967  13183
# 1  2012   A형(RH(+))  경기  43734  15495
# 2  2012   B형(RH(+))  경기  34173  13135
# 3  2012  AB형(RH(+))  경기  14840   5371
# 4  2012   O형(RH(-))  경기    167     69
# 5  2012   A형(RH(-))  경기    211     75
# 6  2012   B형(RH(-))  경기    164     73
# 7  2012  AB형(RH(-))  경기     61     24

# %%
type2_2013 = type2[type2['년도']==2013]
type2_2013
# Out:
#       년도        혈액형별  지역      남      여
# 8   2013   O형(RH(+))  경기  38164  13834
# 9   2013   A형(RH(+))  경기  47953  16635
# 10  2013   B형(RH(+))  경기  37596  14252
# 11  2013  AB형(RH(+))  경기  16154   5702
# 12  2013   O형(RH(-))  경기    191     71
# 13  2013   A형(RH(-))  경기    253    110
# 14  2013   B형(RH(-))  경기    165     82
# 15  2013  AB형(RH(-))  경기     83     17

# %%
type2_2014 = type2[type2['년도']==2014]
type2_2014
# Out:
#       년도        혈액형별  지역      남      여
# 16  2014   O형(RH(+))  경기  40945  14838
# 17  2014   A형(RH(+))  경기  52008  17736
# 18  2014   B형(RH(+))  경기  40710  15170
# 19  2014  AB형(RH(+))  경기  17573   6225
# 20  2014   O형(RH(-))  경기    238     74
# 21  2014   A형(RH(-))  경기    235    106
# 22  2014   B형(RH(-))  경기    182     71
# 23  2014  AB형(RH(-))  경기     76     19

# %%
type2_2015 = type2[type2['년도']==2015]
type2_2015
# Out:
#       년도        혈액형별  지역      남      여
# 24  2015   O형(RH(+))  경기  43543  16671
# 25  2015   A형(RH(+))  경기  54551  19491
# 26  2015   B형(RH(+))  경기  42434  16220
# 27  2015  AB형(RH(+))  경기  18025   6817
# 28  2015   O형(RH(-))  경기    217     85
# 29  2015   A형(RH(-))  경기    249    100
# 30  2015   B형(RH(-))  경기    191     65
# 31  2015  AB형(RH(-))  경기     64     25

# %%
type2_2016 = type2[type2['년도']==2016]
type2_2016
# Out:
#       년도        혈액형별  지역      남      여
# 32  2016   O형(RH(+))  경기  42464  14269
# 33  2016   A형(RH(+))  경기  52977  16524
# 34  2016   B형(RH(+))  경기  40677  13927
# 35  2016  AB형(RH(+))  경기  17745   5719
# 36  2016   O형(RH(-))  경기    195     78
# 37  2016   A형(RH(-))  경기    208     76
# 38  2016   B형(RH(-))  경기    229     49
# 39  2016  AB형(RH(-))  경기     97     33

# %%
type2_2017 = type2[type2['년도']==2017]
type2_2017
# Out:
#       년도        혈액형별  지역      남      여
# 40  2017   O형(RH(+))  경기  44252  14612
# 41  2017   A형(RH(+))  경기  54580  16741
# 42  2017   B형(RH(+))  경기  41961  13863
# 43  2017  AB형(RH(+))  경기  18206   5632
# 44  2017   O형(RH(-))  경기    267     78
# 45  2017   A형(RH(-))  경기    199     88
# 46  2017   B형(RH(-))  경기    186     50
# 47  2017  AB형(RH(-))  경기     79     19

# %%
type2_2018 = type2[type2['년도']==2018]
type2_2018
# Out:
#       년도        혈액형별  지역      남      여
# 48  2018   O형(RH(+))  경기  42990  13569
# 49  2018   A형(RH(+))  경기  53472  15614
# 50  2018   B형(RH(+))  경기  41226  12738
# 51  2018  AB형(RH(+))  경기  17947   5366
# 52  2018   O형(RH(-))  경기    265     68
# 53  2018   A형(RH(-))  경기    219     75
# 54  2018   B형(RH(-))  경기    185     72
# 55  2018  AB형(RH(-))  경기     89     17

# %%
type2_2019 = type2[type2['년도']==2019]
type2_2019
# Out:
#       년도        혈액형별  지역      남      여
# 56  2019   O형(RH(+))  경기  44329  15195
# 57  2019   A형(RH(+))  경기  53573  16990
# 58  2019   B형(RH(+))  경기  41590  13835
# 59  2019  AB형(RH(+))  경기  18760   5964
# 60  2019   O형(RH(-))  경기    243     78
# 61  2019   A형(RH(-))  경기    218     80
# 62  2019   B형(RH(-))  경기    173     60
# 63  2019  AB형(RH(-))  경기     49     33

# %%
type2_2020 = type2[type2['년도']==2020]
type2_2020
# Out:
#       년도        혈액형별  지역      남      여
# 64  2020   O형(RH(+))  경기  47715  15676
# 65  2020   A형(RH(+))  경기  57364  17809
# 66  2020   B형(RH(+))  경기  45410  14695
# 67  2020  AB형(RH(+))  경기  19922   6250
# 68  2020   O형(RH(-))  경기    231     86
# 69  2020   A형(RH(-))  경기    254     96
# 70  2020   B형(RH(-))  경기    213     71
# 71  2020  AB형(RH(-))  경기     84     26

# %%
type2_2021 = type2[type2['년도']==2021]
type2_2021
# Out:
#       년도        혈액형별  지역      남      여
# 72  2021   O형(RH(+))  경기  46862  16336
# 73  2021   A형(RH(+))  경기  57321  18806
# 74  2021   B형(RH(+))  경기  43970  15191
# 75  2021  AB형(RH(+))  경기  19591   6468
# 76  2021   O형(RH(-))  경기    232     92
# 77  2021   A형(RH(-))  경기    288    109
# 78  2021   B형(RH(-))  경기    211     92
# 79  2021  AB형(RH(-))  경기    127     40

# %%
type3_2012 = type2_2012.drop(columns = ['년도'])
type4_2012 = type3_2012.set_index("혈액형별")
type4_2012
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  34967  13183
# A형(RH(+))   경기  43734  15495
# B형(RH(+))   경기  34173  13135
# AB형(RH(+))  경기  14840   5371
# O형(RH(-))   경기    167     69
# A형(RH(-))   경기    211     75
# B형(RH(-))   경기    164     73
# AB형(RH(-))  경기     61     24

# %%
type3_2013 = type2_2013.drop(columns = ['년도'])
type4_2013 = type3_2013.set_index("혈액형별")
type4_2013
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  38164  13834
# A형(RH(+))   경기  47953  16635
# B형(RH(+))   경기  37596  14252
# AB형(RH(+))  경기  16154   5702
# O형(RH(-))   경기    191     71
# A형(RH(-))   경기    253    110
# B형(RH(-))   경기    165     82
# AB형(RH(-))  경기     83     17

# %%
type3_2014 = type2_2014.drop(columns = ['년도'])
type4_2014 = type3_2014.set_index("혈액형별")
type4_2014
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  40945  14838
# A형(RH(+))   경기  52008  17736
# B형(RH(+))   경기  40710  15170
# AB형(RH(+))  경기  17573   6225
# O형(RH(-))   경기    238     74
# A형(RH(-))   경기    235    106
# B형(RH(-))   경기    182     71
# AB형(RH(-))  경기     76     19

# %%
type3_2015 = type2_2015.drop(columns = ['년도'])
type4_2015 = type3_2015.set_index("혈액형별")
type4_2015
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  43543  16671
# A형(RH(+))   경기  54551  19491
# B형(RH(+))   경기  42434  16220
# AB형(RH(+))  경기  18025   6817
# O형(RH(-))   경기    217     85
# A형(RH(-))   경기    249    100
# B형(RH(-))   경기    191     65
# AB형(RH(-))  경기     64     25

# %%
type3_2016 = type2_2016.drop(columns = ['년도'])
type4_2016 = type3_2016.set_index("혈액형별")
type4_2016
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  42464  14269
# A형(RH(+))   경기  52977  16524
# B형(RH(+))   경기  40677  13927
# AB형(RH(+))  경기  17745   5719
# O형(RH(-))   경기    195     78
# A형(RH(-))   경기    208     76
# B형(RH(-))   경기    229     49
# AB형(RH(-))  경기     97     33

# %%
type3_2017 = type2_2017.drop(columns = ['년도'])
type4_2017 = type3_2017.set_index("혈액형별")
type4_2017
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  44252  14612
# A형(RH(+))   경기  54580  16741
# B형(RH(+))   경기  41961  13863
# AB형(RH(+))  경기  18206   5632
# O형(RH(-))   경기    267     78
# A형(RH(-))   경기    199     88
# B형(RH(-))   경기    186     50
# AB형(RH(-))  경기     79     19

# %%
type3_2018 = type2_2018.drop(columns = ['년도'])
type4_2018 = type3_2018.set_index("혈액형별")
type4_2018
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  42990  13569
# A형(RH(+))   경기  53472  15614
# B형(RH(+))   경기  41226  12738
# AB형(RH(+))  경기  17947   5366
# O형(RH(-))   경기    265     68
# A형(RH(-))   경기    219     75
# B형(RH(-))   경기    185     72
# AB형(RH(-))  경기     89     17

# %%
type3_2019 = type2_2019.drop(columns = ['년도'])
type4_2019 = type3_2019.set_index("혈액형별")
type4_2019
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  44329  15195
# A형(RH(+))   경기  53573  16990
# B형(RH(+))   경기  41590  13835
# AB형(RH(+))  경기  18760   5964
# O형(RH(-))   경기    243     78
# A형(RH(-))   경기    218     80
# B형(RH(-))   경기    173     60
# AB형(RH(-))  경기     49     33

# %%
type3_2020 = type2_2020.drop(columns = ['년도'])
type4_2020 = type3_2020.set_index("혈액형별")
type4_2020
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  47715  15676
# A형(RH(+))   경기  57364  17809
# B형(RH(+))   경기  45410  14695
# AB형(RH(+))  경기  19922   6250
# O형(RH(-))   경기    231     86
# A형(RH(-))   경기    254     96
# B형(RH(-))   경기    213     71
# AB형(RH(-))  경기     84     26

# %%
type3_2021 = type2_2021.drop(columns = ['년도'])
type4_2021 = type3_2021.set_index("혈액형별")
type4_2021
# Out:
#             지역      남      여
# 혈액형별
# O형(RH(+))   경기  46862  16336
# A형(RH(+))   경기  57321  18806
# B형(RH(+))   경기  43970  15191
# AB형(RH(+))  경기  19591   6468
# O형(RH(-))   경기    232     92
# A형(RH(-))   경기    288    109
# B형(RH(-))   경기    211     92
# AB형(RH(-))  경기    127     40

# %%
type5_location1 = type4_2012.groupby(['혈액형별'])
type5_location1
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2012_graph = type4_2012.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2012년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location2 = type4_2013.groupby(['혈액형별'])
type5_location2
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2013_graph = type4_2013.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2013년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location3 = type4_2014.groupby(['혈액형별'])
type5_location3
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2014_graph = type4_2014.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2014년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location4 = type4_2015.groupby(['혈액형별'])
type5_location4
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2015_graph = type4_2015.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2015년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location5 = type4_2016.groupby(['혈액형별'])
type5_location5
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2016_graph = type4_2016.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2016년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location6 = type4_2017.groupby(['혈액형별'])
type5_location6
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2017_graph = type4_2017.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2017년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location7 = type4_2018.groupby(['혈액형별'])
type5_location7
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2018_graph = type4_2018.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2018년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location8 = type4_2019.groupby(['혈액형별'])
type5_location8
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2019_graph = type4_2019.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2019년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location9 = type4_2020.groupby(['혈액형별'])
type5_location9
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2020_graph = type4_2020.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2020년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

type5_location10 = type4_2021.groupby(['혈액형별'])
type5_location10
plt.figure(figsize=(8,10))
plt.rcParams.update({'font.size': 8})
type5_2021_graph = type4_2021.plot(kind=('bar'))
plt.xticks(rotation = 0)
plt.title('2021년 혈액형별 헌혈실적')
plt.ylabel("실적")
plt.show()

# %%
type4_2012.plot()
plt.title('2012년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2013.plot()
plt.title('2013년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2014.plot()
plt.title('2014년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2015.plot()
plt.title('2015년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2016.plot()
plt.title('2016년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2017.plot()
plt.title('2017년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2018.plot()
plt.title('2018년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2019.plot()
plt.title('2019년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2020.plot()
plt.title('2020년 혈액형별 헌혈실적')
plt.ylabel("실적")

type4_2021.plot()
plt.title('2021년 혈액형별 헌혈실적')
plt.ylabel("실적")
# Out:
# Text(0, 0.5, '실적')
