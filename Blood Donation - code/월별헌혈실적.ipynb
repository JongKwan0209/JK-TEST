# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
print(fm.findSystemFonts(fontpaths=None, fontext='ttf'))
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['C:\\WINDOWS\\Fonts\\BOD_BLAR.TTF', 'C:\\WINDOWS\\Fonts\\phagspa.ttf', 'C:\\WINDOWS\\Fonts\\RAGE.TTF', 'C:\\WINDOWS\\Fonts\\WINGDNG2.TTF', 'C:\\Windows\\Fonts\\micross.ttf', 'C:\\WINDOWS\\Fonts\\georgia.ttf', 'C:\\WINDOWS\\Fonts\\GOTHICI.TTF', 'C:\\WINDOWS\\Fonts\\BOD_CI.TTF', 'C:\\WINDOWS\\Fonts\\SIMLI.TTF', 'C:\\WINDOWS\\Fonts\\timesbd.ttf', 'C:\\WINDOWS\\Fonts\\YuGothM.ttc', 'C:\\Windows\\Fonts\\LeelawUI.ttf', 'C:\\Windows\\Fonts\\constanb.ttf', 'C:\\Windows\\Fonts\\PERB____.TTF', 'C:\\WINDOWS\\Fonts\\corbelb.ttf', 'C:\\WINDOWS\\Fonts\\ERASBD.TTF', 'C:\\WINDOWS\\Fonts\\corbell.ttf', 'C:\\Windows\\Fonts\\HMKMAMI.TTF', 'C:\\WINDOWS\\Fonts\\BSSYM7.TTF', 'C:\\Windows\\Fonts\\LFAXDI.TTF', 'C:\\WINDOWS\\Fonts\\BELL.TTF', 'C:\\Windows\\Fonts\\HTOWERT.TTF', 'C:\\Windows\\Fonts\\NGULIM.TTF', 'C:\\Windows\\Fonts\\segoeuisl.ttf', 'C:\\WINDOWS\\Fonts\\H2HDRM.TTF', 'C:\\Windows\\Fonts\\ERASBD.TTF', 'C:\\Windows\\Fonts\\LSANSDI.TTF', 'C:\\Windows\\Fonts\\BOOKOSBI.TTF', 'C:\\WINDOWS\\Fonts\\ari
# ...

# %%
df = pd.read_excel("C:/Users/SAMSUNG/Desktop/project/month.xlsx", skiprows=7)
df2 = df.drop(['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93', 'Unnamed: 94', 'Unnamed: 95', 'Unnamed: 96', 'Unnamed: 97', 'Unnamed: 98', 'Unnamed: 99', 'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 104', 'Unnamed: 105', 'Unnamed: 106', 'Unnamed: 107', 'Unnamed: 108'], axis = 1)
df_men = df2.drop(columns = ['여(헌혈실적)'])
df_men2 = df_men.set_index("년도, 월")
df_men2
# Out:
#            남(헌혈실적)
# 년도, 월
# 2013년 1월     11666
# 2013년 2월      9818
# 2013년 3월     12371
# 2013년 4월     11743
# 2013년 5월     11475
# ...            ...
# 2021년 8월     14695
# 2021년 9월     13151
# 2021년 10월    14120
# 2021년 11월    14218
# 2021년 12월    15274
#
# [108 rows x 1 columns]

# %%
df_men = df_men[['년도, 월', '남(헌혈실적)']]

# %%
plt.figure(figsize=(18, 10))
plt.rcParams.update({'font.size': 16})
ax = df.set_index('년도, 월')['남(헌혈실적)'].plot(kind='line', marker='d')
ax.set_ylabel("남(헌혈실적)")
ax.set_xlabel("년도, 월")
plt.title('<월별 남자 헌혈실적>')
plt.show()

# %%
df_women = df2.drop(columns = ['남(헌혈실적)'])
df_women2 = df_women.set_index("년도, 월")
df_women2
# Out:
#            여(헌혈실적)
# 년도, 월
# 2013년 1월      4150
# 2013년 2월      3411
# 2013년 3월      3268
# 2013년 4월      4629
# 2013년 5월      4970
# ...            ...
# 2021년 8월      4714
# 2021년 9월      4566
# 2021년 10월     4448
# 2021년 11월     4600
# 2021년 12월     5292
#
# [108 rows x 1 columns]

# %%
df_women = df_women[['년도, 월', '여(헌혈실적)']]

# %%
plt.figure(figsize=(18, 10))
plt.rcParams.update({'font.size': 16})
ax = df.set_index('년도, 월')['여(헌혈실적)'].plot(kind='line', marker='d')
ax.set_ylabel("여(헌혈실적)")
ax.set_xlabel("년도, 월")
plt.title('<월별 여자 헌혈실적>')
plt.show()

# %%
df2.describe()
# Out:
#             남(헌혈실적)      여(헌혈실적)
# count    108.000000   108.000000
# mean   13159.675926  4423.805556
# std     1179.813670   619.583467
# min     9818.000000  3268.000000
# 25%    12459.250000  4006.250000
# 50%    13272.500000  4432.000000
# 75%    13939.750000  4745.000000
# max    16126.000000  6024.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   년도, 월    108 non-null    object
#  1   남(헌혈실적)  108 non-null    int64
#  2   여(헌혈실적)  108 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 2.7+ KB

# %%
df2.corr()
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_19832\1778878097.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#          남(헌혈실적)  여(헌혈실적)
# 남(헌혈실적)  1.00000  0.61516
# 여(헌혈실적)  0.61516  1.00000

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot(kind='scatter',x='남(헌혈실적)', y='여(헌혈실적)')
# Out:
# <AxesSubplot:xlabel='남(헌혈실적)', ylabel='여(헌혈실적)'>
